# %%
from exa_py import Exa
exa = Exa('API Key')

# %% [markdown]
# # Hidden
#
# Initial setup was hidden to avoid displaying the API key. It was setup as follows:
#
# fromexa_py import Exa
#
# exa = Exa('My-API-Key')

# %% [markdown]
# # Query Search
#
# I went ahead and searched, "Best restaurants in Madison, Wisconsin" and got the following results:

# %%
query = input("Enter your search query: ")
response = exa.search(
    query,        
    num_results=10
)

print(response)
# Out:
# Title: THE 10 BEST Restaurants in Madison (Updated August ...
# URL: https://www.tripadvisor.com/Restaurants-g60859-Madison_Wisconsin.html
# ID: https://www.tripadvisor.com/Restaurants-g60859-Madison_Wisconsin.html
# Score: None
# Published Date: 2025-01-01T00:00:00.000Z
# Author:
# Image: https://dynamic-media-cdn.tripadvisor.com/media/photo-o/08/9a/c6/02/the-old-fashioned.jpg?w=600&h=600&s=1
# Favicon: https://static.tacdn.com/img2/brand_refresh_2025/application_icons/favicon_2025.ico
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: None
#
#
# Title: The Best Restaurants in Madison, Wisconsin
# URL: https://chicago.eater.com/maps/best-restaurants-madison-wisconsin
# ID: https://chicago.eater.com/maps/best-restaurants-madison-wisconsin
# Score: None
# Published Date: 2021-06-28T17:40:44.000Z
# Author: Kyle Nabilcy
# ...
